# %%
import pandas as pd

# %%
cluster17 = pd.read_csv("cluster17.csv")
final_data_regata = pd.read_csv("final_data_regata.csv", low_memory=False)

# %%
final_data_regata = final_data_regata.iloc[:, 1:]
print(final_data_regata.shape)
final_data_regata.head()
# Out:
# (92878, 15)
#    ID Resultado  ID Competidor Nome Competidor  ID Competição  Classe Vela  \
# 0           NaN            NaN     MINA MOBEKK            NaN  IQFOIL FEM.
# 1           NaN            NaN     MINA MOBEKK            NaN  IQFOIL FEM.
# 2           NaN            NaN     MINA MOBEKK            NaN  IQFOIL FEM.
# 3           NaN            NaN     MINA MOBEKK            NaN  IQFOIL FEM.
# 4           NaN            NaN     MINA MOBEKK            NaN  IQFOIL FEM.
#
#   Pontuação Regata  Descarte Flotilha Posição Geral Punição Pontuação Total  \
# 0             15.0         0      NaN             1       0             207
# 1              2.0         0      NaN             1       0             207
# 2              6.0         0      NaN             1       0             207
# 3              3.0         0      NaN             1       0             207
# 4              3.0         0      NaN             1       0             207
#
# ...

# %%
cluster17["Classe Vela"] = cluster17["Classe Vela"].str.upper()
print(cluster17.shape)
cluster17.head()
# Out:
# (13329, 15)
#   ID Resultado ID Competidor    Nome Competidor ID Competição Classe Vela  \
# 0            -             -  ANNE-MARIE RINDOM             -      ILCA 6
# 1            -             -  MARIT BOUWMEESTER             -      ILCA 6
# 2            -             -      EVI VAN ACKER             -      ILCA 6
# 3            -             -     TUULA TENKANEN             -      ILCA 6
# 4            -             -     JOSEFIN OLSSON             -      ILCA 6
#
#    Pontuação Regata  Descarte Flotilha  Posição Geral Punição  \
# 0               1.0         0     Gold              1       0
# 1               2.0         0     Gold              2       0
# 2               2.0         0     Gold              3       0
# 3              12.0         1     Gold              4       0
# 4              20.0         1     Gold              5       0
#
#    Pontuação Total  Nett          Nome Competição Regata Nacionalidade
# ...

# %%
dF_final = pd.concat([final_data_regata, cluster17])

# %%
dF_final.head()
# Out:
#   ID Resultado ID Competidor Nome Competidor ID Competição  Classe Vela  \
# 0          NaN           NaN     MINA MOBEKK           NaN  IQFOIL FEM.
# 1          NaN           NaN     MINA MOBEKK           NaN  IQFOIL FEM.
# 2          NaN           NaN     MINA MOBEKK           NaN  IQFOIL FEM.
# 3          NaN           NaN     MINA MOBEKK           NaN  IQFOIL FEM.
# 4          NaN           NaN     MINA MOBEKK           NaN  IQFOIL FEM.
#
#   Pontuação Regata  Descarte Flotilha Posição Geral Punição Pontuação Total  \
# 0             15.0         0      NaN             1       0             207
# 1              2.0         0      NaN             1       0             207
# 2              6.0         0      NaN             1       0             207
# 3              3.0         0      NaN             1       0             207
# 4              3.0         0      NaN             1       0             207
#
#   Nett             Nome Competição Regata Nacionalidade
# ...

# %%
dF_final.to_csv("final_data_regata.csv", index=False)
